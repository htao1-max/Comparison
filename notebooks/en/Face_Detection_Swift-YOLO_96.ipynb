# %% [markdown]
# <div align="center">
#   <h1>Welcom to SSCMA for Google Colab Training Example 🔥 </h1>
#   <a href="https://sensecraftma.seeed.cc/" target="_blank"><img width="20%" src="https://files.seeedstudio.com/sscma/docs/images/SSCMA-Hero.png"></a>
# </div>

# %% [markdown]
# ## ⚠️ Important Notice
#
# Before you begin, please ensure:
#
# 1. **Enable GPU Acceleration**: Click `Runtime` → `Change runtime type` → Select `GPU` in `Hardware accelerator`
# 2. **Colab Version Requirement**: **You MUST use Colab version 2025.07** for compatibility. Other versions may cause unexpected errors.
#
# If you encounter version-related issues, you can run the following commands in the first code cell to check your environment:
#
# ```python
# # Check if GPU is available
# !nvidia-smi
#
# # Check Python version
# !python --version
# ```

# %% [markdown]
# # Face Detection - Swift-YOLO
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/seeed-studio/sscma-model-zoo/blob/main/notebooks/en/Face_Detection_Swift-YOLO_96.ipynb)
#
# **Version:** 1.0.0
#
# **Category:** Object Detection
#
# **Algorithm:** [Swift-YOLO](configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py)
#
# **Dataset:** [face detection](https://universe.roboflow.com/detection-02p2y/face-b3jhr/dataset/2)
#
# **⚠️ IMPORTANT: To download the dataset, you need to set your Roboflow API key.**
#
# 1. Go to your [Roboflow Settings](https://app.roboflow.com/settings/api).
# 2. Copy your private API key.
# 3. In Colab, click the **key icon** on the **left sidebar** to open Secrets.
# 4. Add a new secret named `ROBOFLOW_API_KEY` with your API key as the value.
#
# **Class:** `face`
#
# ![Face Detection](https://files.seeedstudio.com/sscma/static/detection_face.png)
#
# The model is a Swift-YOLO model trained on the face detection dataset.

# %% [markdown]
# ## ⚙️Prerequisites
# ### Setup SSCMA
# Clone the [repository](https://github.com/Seeed-Studio/ModelAssistant) and install the dependencies.

# %%
# !pip install ethos-u-vela
# !git clone https://github.com/Seeed-Studio/ModelAssistant.git -b 2.0.0  #clone the repo
# %cd ModelAssistant

# !. ./scripts/setup_colab.sh
# Out:
# Requirement already satisfied: ethos-u-vela in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: flatbuffers==24.3.25 in /usr/local/lib/python3.12/dist-packages (from ethos-u-vela) (24.3.25)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ethos-u-vela) (1.26.4)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 894.6/894.6 kB 23.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# openxlab 0.0.38 requires setuptools~=60.2.0, but you have setuptools 69.5.1 which is incompatible.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pymc 5.28.0 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu128/torch2.10.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mmengine) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from mmengine) (6.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from mmengine) (3.3.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.12/dist-packages (from mmengine) (4.11.0.86)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->mmengine) (2.19.2)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.12/dist-packages (from yapf->mmengine) (4.9.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 16.7 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 31.9 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.7 yapf-0.43.0
# Cloning into 'ModelAssistant'...
# remote: Enumerating objects: 15755, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 15755 (delta 7), reused 17 (delta 2), pack-reused 15719 (from 1)
# Receiving objects: 100% (15755/15755), 26.61 MiB | 23.25 MiB/s, done.
# Resolving deltas: 100% (9182/9182), done.
# /content/ModelAssistant/ModelAssistant/ModelAssistant/ModelAssistant/ModelAssistant
# Checking if CUDA available... OK
# ERROR: Could not find a version that satisfies the requirement torch==2.0.0 (from versions: 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1, 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0)
# ERROR: No matching distribution found for torch==2.0.0
# Installing base deps... Collecting TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl (from -r requirements/export.txt (line 2))
#   Using cached https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl (416 kB)
# Requirement already satisfied: albumentations<=1.3.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 2)) (1.3.1)
# Requirement already satisfied: libusb1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 3)) (3.3.1)
# Requirement already satisfied: cbor in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 7)) (1.0.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 8)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 13)) (4.11.0.86)
# Requirement already satisfied: openmim>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 17)) (0.3.9)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 18)) (26.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 19)) (2.2.2)
# Requirement already satisfied: pillow>=9.4.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 20)) (11.3.0)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 21)) (6.0.3)
# Requirement already satisfied: scikit-image>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 22)) (0.25.2)
# Requirement already satisfied: scikit-learn>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 23)) (1.6.1)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 27)) (0.13.1)
# Requirement already satisfied: tensorboard>=2.12.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 31)) (2.19.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 32)) (4.65.2)
# Requirement already satisfied: pyvww in /usr/local/lib/python3.12/dist-packages (from -r requirements/base.txt (line 36)) (0.1.1)
# Requirement already satisfied: pnnx==0.0.4 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 2)) (0.0.4)
# Requirement already satisfied: ncnn>=1.0.20230517 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 3)) (1.0.20260114)
# Requirement already satisfied: onnx>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 4)) (1.20.1)
# Requirement already satisfied: onnxmltools>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 5)) (1.16.0)
# Requirement already satisfied: onnxruntime>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 6)) (1.24.3)
# Requirement already satisfied: onnxsim>=0.4.33 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 7)) (0.6.2)
# Requirement already satisfied: protobuf>=4.23.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 8)) (5.29.6)
# Requirement already satisfied: tensorflow>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/inference.txt (line 9)) (2.19.0)
# Requirement already satisfied: ethos-u-vela in /usr/local/lib/python3.12/dist-packages (from -r requirements/export.txt (line 8)) (5.0.0)
# Requirement already satisfied: black>=23.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/tests.txt (line 1)) (26.1.0)
# Requirement already satisfied: isort>=5.12.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements/tests.txt (line 2)) (8.0.1)
# Requirement already satisfied: pre-commit>=3.3.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements/tests.txt (line 3)) (4.5.1)
# Requirement already satisfied: ruff>=0.0.275 in /usr/local/lib/python3.12/dist-packages (from -r requirements/tests.txt (line 4)) (0.15.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from albumentations<=1.3.1->-r requirements/base.txt (line 2)) (1.16.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.12/dist-packages (from albumentations<=1.3.1->-r requirements/base.txt (line 2)) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.12/dist-packages (from albumentations<=1.3.1->-r requirements/base.txt (line 2)) (4.11.0.86)
# Requirement already satisfied: Click in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (8.3.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.1.11)
# Requirement already satisfied: opendatalab in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.0.10)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (2.28.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 19)) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements/base.txt (line 19)) (2025.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 22)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 22)) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 22)) (2026.2.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.20.0->-r requirements/base.txt (line 22)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.2->-r requirements/base.txt (line 23)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.2->-r requirements/base.txt (line 23)) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->-r requirements/base.txt (line 27)) (2.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (1.78.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (3.10.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (69.5.1)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (3.1.6)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.12/dist-packages (from pyvww->-r requirements/base.txt (line 36)) (2.0.11)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from pyvww->-r requirements/base.txt (line 36)) (0.25.0+cu128)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from ncnn>=1.0.20230517->-r requirements/inference.txt (line 3)) (3.2.0)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->-r requirements/inference.txt (line 4)) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.14.0->-r requirements/inference.txt (line 4)) (0.5.4)
# Requirement already satisfied: skl2onnx>=1.4.9 in /usr/local/lib/python3.12/dist-packages (from onnxmltools>=1.11.2->-r requirements/inference.txt (line 5)) (1.20.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (1.14.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (2.1.1)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (3.15.1)
# Requirement already satisfied: ruamel.yaml>=0.16.12 in /usr/local/lib/python3.12/dist-packages (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2)) (0.19.1)
# Requirement already satisfied: igraph>=0.9 in /usr/local/lib/python3.12/dist-packages (from TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2)) (1.0.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (1.0.4)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.12/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (4.9.2)
# Requirement already satisfied: pytokens>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from black>=23.3.0->-r requirements/tests.txt (line 1)) (0.4.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (2.6.17)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (21.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.46.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->-r requirements/base.txt (line 27)) (3.0)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from igraph>=0.9->TinyNeuralNetwork@ https://files.seeedstudio.com/sscma/library/TinyNeuralNetwork-0.1.1-py3-none-any.whl->-r requirements/export.txt (line 2)) (1.7.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow>=2.12.0->-r requirements/inference.txt (line 9)) (0.19.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 17)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 17)) (3.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 17)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->openmim>=0.3.7->-r requirements/base.txt (line 17)) (2026.2.25)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.24.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (3.24.3)
# Requirement already satisfied: python-discovery>=1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.3.3->-r requirements/tests.txt (line 3)) (1.1.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.12.3->-r requirements/base.txt (line 31)) (3.0.3)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.12/dist-packages (from model-index->openmim>=0.3.7->-r requirements/base.txt (line 17)) (4.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.12/dist-packages (from opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (3.23.0)
# Requirement already satisfied: openxlab in /usr/local/lib/python3.12/dist-packages (from opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.0.38)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->openmim>=0.3.7->-r requirements/base.txt (line 17)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->openmim>=0.3.7->-r requirements/base.txt (line 17)) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.15.1->-r requirements/inference.txt (line 6)) (1.3.0)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->pyvww->-r requirements/base.txt (line 36)) (2.10.0+cu128)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0->torchvision->pyvww->-r requirements/base.txt (line 36)) (1.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.1.2)
# Requirement already satisfied: oss2~=2.17.0 in /usr/local/lib/python3.12/dist-packages (from openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (2.17.0)
# Collecting setuptools>=41.0.0 (from tensorboard>=2.12.3->-r requirements/base.txt (line 31))
#   Using cached setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.12/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /usr/local/lib/python3.12/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (2.16.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim>=0.3.7->-r requirements/base.txt (line 17)) (43.0.3)
# Using cached setuptools-60.2.0-py3-none-any.whl (953 kB)
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 69.5.1
#     Uninstalling setuptools-69.5.1:
#       Successfully uninstalled setuptools-69.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# pytensor 2.38.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pymc 5.28.0 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# Successfully installed setuptools-60.2.0
# Installing OpenMIM deps...
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 5, in <module>
#     from mim.cli import cli
#   File "/usr/local/lib/python3.12/dist-packages/mim/__init__.py", line 10, in <module>
#     import setuptools  # noqa: F401
#     ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/setuptools/__init__.py", line 16, in <module>
#     import setuptools.version
#   File "/usr/local/lib/python3.12/dist-packages/setuptools/version.py", line 1, in <module>
#     import pkg_resources
#   File "/usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py", line 2172, in <module>
#     register_finder(pkgutil.ImpImporter, find_on_path)
#                     ^^^^^^^^^^^^^^^^^^^
# AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
# OpenMIM install deps failed... Exiting

# %% [markdown]
# ### Download the pretrain model weights file

# %%
# %mkdir -p Face_Detection_Swift-YOLO_96
# !wget -c https://files.seeedstudio.com/sscma/model_zoo/detection/face_detection/swift_yolo_1xb16_300e_coco_300_sha1_fe1d7dec30d62e583a7ccf717fd6585c792570bf.pth -O Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ### Download the dataset

# %%
# %mkdir -p Face_Detection_Swift-YOLO_96
# !pip install roboflow
import os
from google.colab import userdata
os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")
from roboflow import download_dataset
dataset = download_dataset("https://app.roboflow.com/ds/JuYoeNEVdZ?key=r5MyDV2W32", "coco")
dataset_path = dataset.location
import shutil
shutil.move(dataset_path, "Face_Detection_Swift-YOLO_96/dataset")

# %% [markdown]
# ## 🚀Train a model with SSCMA
# All the training parameters are in the `config.py` file, you can change the parameters to train your own model.
#
# Below are explanations of some common parameters. You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/config) for more details.
# - `data_root` - the datasets path.
# - `epochs`- the train epochs. **we use 10 epochs as an example**.
# - `batch_size` - the batch size.
# - `height` - the image height.
# - `width` - the image width.
# - `load_from` - the pretrained model path.
# - `num_classes` - the number of classes.
#
# You can overwrite the parameters in the `config.py` file by using the `--cfg-options` argument.
# ```bash
# # Example
# sscma.train config.py --cfg-options data_root=./datasets/test_dataset epochs=10
# ```

# %%
# !sscma.train configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py \
--cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ## 📦Export the model
# After training, you can export the model to the format for deployment. SSCMA supports exporting to ONNX, and TensorFlow Lite at present.
# You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/export/overview) for more details.
#
# ```bash
# python3 tools/export.py \
#     "<CONFIG_FILE_PATH>" \
#     "<CHECKPOINT_FILE_PATH>"
# ```

# %%
import os
with open('Face_Detection_Swift-YOLO_96/last_checkpoint', 'r') as f:
	os.environ['CHECKPOINT_FILE_PATH'] = f.read()

# %%
# !sscma.export configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py $CHECKPOINT_FILE_PATH --cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ### 📝Evaluate the model
# After exporting the model, you can evaluate the model on the test dataset.
# You can also refer to the [documentation](https://sensecraftma.seeed.cc/tutorials/export/overview) for more details.
#
#
# ```bash
# python3 tools/inference.py \
#     "<CONFIG_FILE_PATH>" \
#     "<CHECKPOINT_FILE_PATH>"
# ```

# %% [markdown]
# ### Evaluate the PyTorch model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}.pth \
--cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ### Evaluate the ONNX model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_float32.onnx \
--cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ### Evaluate the TFLite FLOAT32 model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_float32.tflite \
--cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ### Evaluate the TFLite INT8 model

# %%
# !sscma.inference configs/swift_yolo/swift_yolo_tiny_1xb16_300e_coco.py ${CHECKPOINT_FILE_PATH%.*}_int8.tflite \
--cfg-options  \
    work_dir=Face_Detection_Swift-YOLO_96 \
    num_classes=1 \
    epochs=10  \
    height=96 \
    width=96 \
    data_root=Face_Detection_Swift-YOLO_96/dataset/ \
    load_from=Face_Detection_Swift-YOLO_96/pretrain.pth

# %% [markdown]
# ## 🤖 Deploy the model
# After model training, evaluation and export, you can deploy the model to your device. You can refer to [Documentation](https://sensecraftma.seeed.cc/deploy/overview) for more details.

# %%
# %ls -lh Face_Detection_Swift-YOLO_96/

# %% [markdown]
# ### Thanks for Trying Out SSCMA 🎉
#
# Congratulations, you have completed this tutorial. If you are interested in more application scenarios or our projects, please feel free to give [SSCMA](https://github.com/Seeed-Studio/ModelAssistant) a star ✨ on GitHub.
#
# If you have any questions about this tutorial, please also feel free to [submit an issue](https://github.com/Seeed-Studio/ModelAssistant/issues).
